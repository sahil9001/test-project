# %%
# !source venv/bin/activate

# %%
from mclp import *
# %matplotlib inline

# %%
import numpy as np
Npoints = 300
# Generate points in uniform distribution 
# points = np.random.rand(Npoints,2)

# Generate points in moon distribution
from sklearn.datasets import make_moons
points,_ = make_moons(Npoints,noise=0.15)
# Plot input data
plot_input(points)

# %%
# Number of sites to select
K = 20

# Service radius of each site
radius = 0.2

# Candidate site size (random sites generated)
M = 100

# Run mclp opt_sites is the location of optimal sites and f is the points covered
opt_sites,f = mclp(points,K,radius,M)

# Plot the result
plot_result(points,opt_sites,radius)
# Out:
# ----- Configurations -----
#   Number of points 300
#   K 20
#   Radius 0.2
#   M 100
# Restricted license - for non-production use only - expires 2024-10-28
# ----- Output -----
#   Running time : 0.22647929191589355 seconds
#   Optimal coverage points: 203

# %%
K = 20
radius = 0.2
M = 10000
opt_sites,f = mclp(points,K,radius,M)
plot_result(points,opt_sites,radius)
# Out:
# ----- Configurations -----
#   Number of points 300
#   K 20
#   Radius 0.2
#   M 10000
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In [12], line 4
#       2 radius = 0.2
#       3 M = 10000
# ----> 4 opt_sites,f = mclp(points,K,radius,M)
#       5 plot_result(points,opt_sites,radius)
#
# File ~/Desktop/test/mclp.py:75, in mclp(points, K, radius, M)
#      73 m.setObjective(quicksum(y[i]for i in range(I)),GRB.MAXIMIZE)
#      74 m.setParam('OutputFlag', 0)
# ---> 75 m.optimize()
#      76 end = time.time()
#      77 print('----- Output -----')
#
# File src/gurobipy/model.pxi:875, in gurobipy.Model.optimize()
#
# GurobiError: Model too large for size-limited license; visit https://www.gurobi.com/free-trial for a full license
